# %%
# !pip install ripser

# %%
# !pip install nba_api

# %%
import pandas as pd
import numpy as np
from nba_api.stats.endpoints import commonteamroster
from nba_api.stats.static import teams
from tqdm import tqdm
from scipy import stats

# %%
def load_play_type_data(offensive_types, defensive_types):
  offensive_data = {}
  for i in offensive_types:
    offensive_data[i] = pd.read_csv(i + "_offense.csv")

  defensive_data = {}
  for i in defensive_types:
    defensive_data[i] = pd.read_csv(i + "_defense.csv")

  return offensive_data, defensive_data

# %%
def load_normalized_play_type_data(offensive_types, defensive_types):
  offensive_data = {}
  for i in offensive_types:
    offensive_data[i] = pd.read_csv(i + "_offense.csv").dropna()
    offensive_data[i]['REL_PPP'] = stats.zscore(offensive_data[i]["PPP"])
  defensive_data = {}
  for i in defensive_types:
    defensive_data[i] = pd.read_csv(i + "_defense.csv").dropna()

    INV_PPP = 1.0 / defensive_data[i]["PPP"]
    INV_PPP[np.isinf(INV_PPP)] = 0.0
    defensive_data[i]["REL_PPP"] = stats.zscore(INV_PPP)

  return offensive_data, defensive_data

# %%
def generate_team_space(player_names, offensive_data, defensive_data):
  team_data = [] * len(player_names)
  for i in range(len(player_names)):
    player_data = []
    for play_type in offensive_data.keys():
      df = offensive_data[play_type]
      if player_names[i] in df['PLAYER'].values:
        player_data.append(df[df['PLAYER'] == player_names[i]]['REL_PPP'].values[0])
      else:
        player_data.append(0.0)

    for play_type in defensive_data.keys():
      df = defensive_data[play_type]
      if player_names[i] in df['PLAYER'].values:
        player_data.append(df[df['PLAYER'] == player_names[i]]['REL_PPP'].values[0])
      else:
        player_data.append(0.0)

    team_data.append(player_data)

  return np.array(team_data)

# %%
def generate_team_offensive_space(player_names, offensive_data):
  team_data = [] * len(player_names)
  for i in range(len(player_names)):
    player_data = []
    for play_type in offensive_data.keys():
      df = offensive_data[play_type]
      if player_names[i] in df['PLAYER'].values:
        player_data.append(df[df['PLAYER'] == player_names[i]]['REL_PPP'].values[0])
      else:
        player_data.append(0.0)

    team_data.append(player_data)
  return np.array(team_data)

# %%
def generate_team_defensive_space(player_names, defensive_data):
  team_data = [] * len(player_names)
  for i in range(len(player_names)):
    player_data = []
    for play_type in defensive_data.keys():
      df = defensive_data[play_type]
      if player_names[i] in df['PLAYER'].values:
        player_data.append(df[df['PLAYER'] == player_names[i]]['REL_PPP'].values[0])
      else:
        player_data.append(0.0)

    team_data.append(player_data)
  return np.array(team_data)

# %%
offensive_play_types = [
    'transition',
    'iso',
    'pnr_handler',
    'pnr_roller',
    'spot_up',
    'putback',
    'post_up',
    'off_screen',
    'handoff',
    'cut'
]
no_defensive_stats = ['putback', 'cut', 'transition']
defensive_play_types = [i for i in offensive_play_types if i not in no_defensive_stats]

# %%
#get player rosters
all_team_ids = [i['id'] for i in teams.get_teams()]
all_rosters = [commonteamroster.CommonTeamRoster(team_id=i, season="2023-24").get_data_frames()[0] for i in all_team_ids]

# %%
all_rosters[0]

# %%
#Load play type data
offensive_data, defensive_data = load_normalized_play_type_data(offensive_play_types, defensive_play_types)

# %%
#Generate space matrix for each time
team_space_dict = {}
for team in all_rosters:
  team_id = team['TeamID'].values[0]
  team_space_dict[team_id] = generate_team_space(team["PLAYER"].tolist(), offensive_data, defensive_data)

# %%
maxdim = 1
team_id = []
mean_deaths = {}
std_dev = {}
persistence_vals = {}
homology_objects = {}

for i in range(maxdim):
  mean_deaths[str(i)] = []
  std_dev[str(i)] = []

for team in team_space_dict.keys():
  result = ripser(team_space_dict[team], maxdim=maxdim, do_cocycles=True)
  homology_objects[team] = result
  diagrams = result['dgms']
  persistence_vals[team] = [i for i in diagrams[i][:, 1] if i != np.inf]

  for i in range(maxdim):
    resolutions_at_death = diagrams[i][:, 1]
    mean_deaths[str(i)].append(np.mean([j for j in resolutions_at_death if j != np.inf]))
    std_dev[str(i)].append(np.std([j for j in resolutions_at_death if j != np.inf]))

  team_id.append(team)
# Out:
# /usr/local/lib/python3.10/dist-packages/ripser/ripser.py:247: UserWarning:
#
# The input matrix is square, but the distance_matrix flag is off.  Did you mean to indicate that this was a distance matrix?
#
# /usr/local/lib/python3.10/dist-packages/ripser/ripser.py:253: UserWarning:
#
# The input point cloud has more columns than rows; did you mean to transpose?
#
# /usr/local/lib/python3.10/dist-packages/ripser/ripser.py:247: UserWarning:
#
# The input matrix is square, but the distance_matrix flag is off.  Did you mean to indicate that this was a distance matrix?
#
# /usr/local/lib/python3.10/dist-packages/ripser/ripser.py:247: UserWarning:
#
# The input matrix is square, but the distance_matrix flag is off.  Did you mean to indicate that this was a distance matrix?
#
# /usr/local/lib/python3.10/dist-packages/ripser/ripser.py:247: UserWarning:
#
# The input matrix is square, but the distance_matrix flag is off.  Did you mean to indicate that this was a distance matrix?
#
# /usr/local/lib/python3.10/dist-packages/ripser/ripser.py:247: UserWarning:
#
# The input matrix is square, but the distance_matrix flag is off.  Did you mean to indicate that this was a distance matrix?
#
# /usr/local/lib/python3.10/dist-packages/ripser/ripser.py:247: UserWarning:
#
# The input matrix is square, but the distance_matrix flag is off.  Did you mean to indicate that this was a distance matrix?
#
# /usr/local/lib/python3.10/dist-packages/ripser/ripser.py:253: UserWarning:
#
# The input point cloud has more columns than rows; did you mean to transpose?
#
# /usr/local/lib/python3.10/dist-packages/ripser/ripser.py:247: UserWarning:
#
# The input matrix is square, but the distance_matrix flag is off.  Did you mean to indicate that this was a distance matrix?
#
# /usr/local/lib/python3.10/dist-packages/ripser/ripser.py:247: UserWarning:
#
# The input matrix is square, but the distance_matrix flag is off.  Did you mean to indicate that this was a distance matrix?
#
# /usr/local/lib/python3.10/dist-packages/ripser/ripser.py:247: UserWarning:
#
# The input matrix is square, but the distance_matrix flag is off.  Did you mean to indicate that this was a distance matrix?
#
# /usr/local/lib/python3.10/dist-packages/ripser/ripser.py:253: UserWarning:
#
# The input point cloud has more columns than rows; did you mean to transpose?
#
# /usr/local/lib/python3.10/dist-packages/ripser/ripser.py:247: UserWarning:
#
# The input matrix is square, but the distance_matrix flag is off.  Did you mean to indicate that this was a distance matrix?
#
# /usr/local/lib/python3.10/dist-packages/ripser/ripser.py:247: UserWarning:
#
# The input matrix is square, but the distance_matrix flag is off.  Did you mean to indicate that this was a distance matrix?

# %%
death_df = pd.DataFrame(mean_deaths)
death_df['id'] = team_id
death_df['std'] = list(std_dev.values())[0]

stringed_ids = [teams.find_team_name_by_id(i)['abbreviation'] for i in list(persistence_vals.keys())]
death_df = death_df.merge(pd.json_normalize(teams.get_teams()), left_on="id", right_on="id")
death_df = death_df.drop(["nickname", "city", "state", "year_founded", "full_name"], axis=1)
e_ratings = pd.read_csv("e_ratings.csv")
e_ratings = e_ratings.rename(columns={'TEAM': 'abbreviation'})
death_df = death_df.merge(e_ratings, on="abbreviation")

# %%
death_df
# Out:
#            0         1          id abbreviation  Unnamed: 0  GP   W   L   MIN  \
# 0   3.584194       NaN  1610612737          ATL          23  49  22  27  2372
# 1   2.965598  4.789091  1610612738          BOS           1  50  38  12  2425
# 2   2.983144       NaN  1610612739          CLE           5  47  31  16  2266
# 3   2.866538  3.027956  1610612740          NOP           7  49  28  21  2357
# 4   2.709943       NaN  1610612741          CHI          19  50  23  27  2430
# 5   3.338398       NaN  1610612742          DAL          17  49  26  23  2352
# 6   2.637471       NaN  1610612743          DEN          10  51  35  16  2448
# 7   3.009247       NaN  1610612744          GSW          16  46  21  25  2238
# 8   2.731922       NaN  1610612745          HOU          12  49  23  26  2377
# 9   2.668551  2.979239  1610612746          LAC           3  48  33  15  2309
# 10  3.066487       NaN  1610612747          LAL          19  51  26  25  2468
# 11  2.987320  3.806029  1610612748          MIA          18  50  26  24  2405
# 12  2.909899       NaN  1610612749          MIL           9  50  33  17  2415
# 13  2.889211       NaN  1610612750          MIN           4  50  35  15  2410
# 14  3.108663       NaN  1610612751          BKN          21  48  20  28  2319
# 15  2.997365       NaN  1610612752          NYK           7  50  32  18  2400
# 16  2.888295       NaN  1610612753          ORL          12  50  27  23  2415
# 17  2.713415  3.287298  1610612754          IND          14  51  28  23  2448
# 18  3.215922       NaN  1610612755          PHI           6  48  30  18  2314
# 19  2.520716  3.768147  1610612756          PHX          11  50  29  21  2415
# 20  2.600718  3.437443  1610612757          POR          27  50  15  35  2425
# 21  2.537233       NaN  1610612758          SAC          15  48  29  19  2329
# 22  2.411493       NaN  1610612759          SAS          27  50  10  40  2410
# 23  3.535360       NaN  1610612760          OKC           2  50  35  15  2420
# 24  3.077586       NaN  1610612761          TOR          22  49  17  32  2372
# 25  3.297326       NaN  1610612762          UTA          24  51  25  26  2473
# 26  2.763368       NaN  1610612763          MEM          25  50  18  32  2410
# 27  2.440670       NaN  1610612764          WAS          26  49   9  40  2352
# 28  2.628467  3.093197  1610612765          DET          29  49   6  43  2362
# 29  2.805097       NaN  1610612766          CHA          30  48  10  38  2314
#
#     OFFRTG  DEFRTG  NETRTG
# 0    115.2   117.8    -2.6
# 1    118.2   109.0     9.1
# 2    113.5   108.0     5.5
# 3    115.2   111.0     4.2
# 4    111.3   112.2    -0.9
# 5    115.2   115.5    -0.3
# 6    115.7   112.3     3.4
# 7    115.1   115.0     0.1
# 8    110.8   109.6     1.2
# 9    118.0   110.8     7.2
# 10   111.7   112.5    -0.9
# 11   111.1   111.7    -0.7
# 12   118.2   114.2     4.0
# 13   112.4   105.9     6.5
# 14   113.0   114.2    -1.2
# 15   114.8   110.6     4.2
# 16   110.2   109.0     1.2
# 17   117.9   116.7     1.1
# 18   116.7   111.4     5.3
# 19   115.8   112.8     2.9
# 20   106.1   114.7    -8.6
# 21   114.2   114.0     0.2
# 22   107.4   116.0    -8.6
# 23   117.7   109.2     8.5
# 24   112.5   114.7    -2.2
# 25   113.2   115.9    -2.7
# 26   104.6   111.2    -6.6
# 27   109.4   117.5    -8.1
# 28   109.1   118.4    -9.2
# 29   107.6   118.9   -11.3

# %%
import plotly.express as px
fig = px.scatter(death_df, x="0", y="NETRTG", color="abbreviation")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="941d6910-c640-4340-8abd-4d1fea52e79e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("941d6910-c640-4340-8abd-4d1fea52e79e")) {                    Plotly.newPlot(                        "941d6910-c640-4340-8abd-4d1fea52e79e",                        [{"hovertemplate":"abbreviation=ATL\u003cbr\u003e0=%{x}\u003cbr\u003eNETRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ATL","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"ATL","orientation":"v","showlegend":true,"x":[3.5841939449310303],"xaxis":"x","y":[-2.6],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=BOS\u003cbr\u003e0=%{x}\u003cbr\u003eNETRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BOS","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"BOS","orientation":"v","showlegend":true,"x":[2.965598290616816],"xaxis":"x","y":[9.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=CLE\u003cbr\u003e0=%{x}\u003cbr\u003eNETRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CLE","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"CLE","orientation":"v","showlegend":true,"x":[2.9831443428993225],"xaxis":"x","y":[5.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=NOP\u003cbr\u003e0=%{x}\u003cbr\u003eNETRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NOP","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"NOP","orientation":"v","showlegend":true,"x":[2.86653786439162],"xaxis":"x","y":[4.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=CHI\u003cbr\u003e0=%{x}\u003cbr\u003eNETRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CHI","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"CHI","orientation":"v","showlegend":true,"x":[2.7099430918693543],"xaxis":"x","y":[-0.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=DAL\u003cbr\u003e0=%{x}\u003cbr\u003eNETRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DAL","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"DAL","orientation":"v","showlegend":true,"x":[3.3383983373641968],"xaxis":"x","y":[-0.3],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=DEN\u003cbr\u003e0=%{x}\u003cbr\u003eNETRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEN","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"DEN","orientation":"v","showlegend":true,"x":[2.637470613826405],"xaxis":"x","y":[3.4],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=GSW\u003cbr\u003e0=%{x}\u003cbr\u003eNETRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GSW","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"GSW","orientation":"v","showlegend":true,"x":[3.009247458898104],"xaxis":"x","y":[0.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=HOU\u003cbr\u003e0=%{x}\u003cbr\u003eNETRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"HOU","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"HOU","orientation":"v","showlegend":true,"x":[2.731922301379117],"xaxis":"x","y":[1.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=LAC\u003cbr\u003e0=%{x}\u003cbr\u003eNETRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LAC","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"LAC","orientation":"v","showlegend":true,"x":[2.6685511271158853],"xaxis":"x","y":[7.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=LAL\u003cbr\u003e0=%{x}\u003cbr\u003eNETRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendg ...

# %%
# prompt: fit a linear regression for the above

import statsmodels.api as sm

# Prepare the data
X = death_df["0"].values.reshape(-1, 1)
y = death_df["NETRTG"].values

# Add a constant term to the design matrix
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.106
# Model:                            OLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     3.317
# Date:                Mon, 05 Feb 2024   Prob (F-statistic):             0.0793
# Time:                        18:46:19   Log-Likelihood:                -91.481
# No. Observations:                  30   AIC:                             187.0
# Df Residuals:                      28   BIC:                             189.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -17.2551      9.536     -1.809      0.081     -36.789       2.279
# x1             5.9657      3.276      1.821      0.079      -0.744      12.675
# ==============================================================================
# Omnibus:                        2.514   Durbin-Watson:                   1.502
# Prob(Omnibus):                  0.284   Jarque-Bera (JB):                1.399
# Skew:                          -0.201   Prob(JB):                        0.497
# Kurtosis:                       2.021   Cond. No.                         32.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Try strictly offensively

# %%
team_offensive_space_dict = {}
for team in all_rosters:
  team_id = team['TeamID'].values[0]
  team_offensive_space_dict[team_id] = generate_team_offensive_space(team["PLAYER"].tolist(), offensive_data)

# %%
maxdim = 1
team_id = []
offensive_mean_deaths = {}

for i in range(maxdim):
  offensive_mean_deaths[str(i)] = []

for team in team_offensive_space_dict.keys():
  result = ripser(team_offensive_space_dict[team], maxdim=maxdim, do_cocycles=True)
  diagrams = result['dgms']

  for i in range(maxdim):
    resolutions_at_death = diagrams[i][:, 1]
    offensive_mean_deaths[str(i)].append(np.mean([j for j in resolutions_at_death if j != np.inf]))

  team_id.append(team)

# %%
off_death_df = pd.DataFrame(offensive_mean_deaths)
off_death_df['id'] = team_id
off_death_df = off_death_df.merge(pd.json_normalize(teams.get_teams()), left_on="id", right_on="id")
off_death_df = off_death_df.drop(["nickname", "city", "state", "year_founded", "full_name"], axis=1)
e_ratings = pd.read_csv("e_ratings.csv")
e_ratings = e_ratings.rename(columns={'TEAM': 'abbreviation'})
off_death_df = off_death_df.merge(e_ratings, on="abbreviation")

# %%
off_death_df
# Out:
#            0          id abbreviation  Unnamed: 0  GP   W   L   MIN  OFFRTG  \
# 0   1.923153  1610612737          ATL          23  49  22  27  2372   115.2
# 1   2.448827  1610612738          BOS           1  50  38  12  2425   118.2
# 2   2.211225  1610612739          CLE           5  47  31  16  2266   113.5
# 3   1.965984  1610612740          NOP           7  49  28  21  2357   115.2
# 4   1.625255  1610612741          CHI          19  50  23  27  2430   111.3
# 5   2.099053  1610612742          DAL          17  49  26  23  2352   115.2
# 6   1.967567  1610612743          DEN          10  51  35  16  2448   115.7
# 7   2.375221  1610612744          GSW          16  46  21  25  2238   115.1
# 8   2.120241  1610612745          HOU          12  49  23  26  2377   110.8
# 9   1.815849  1610612746          LAC           3  48  33  15  2309   118.0
# 10  2.066473  1610612747          LAL          19  51  26  25  2468   111.7
# 11  2.006529  1610612748          MIA          18  50  26  24  2405   111.1
# 12  2.121944  1610612749          MIL           9  50  33  17  2415   118.2
# 13  2.160910  1610612750          MIN           4  50  35  15  2410   112.4
# 14  2.308959  1610612751          BKN          21  48  20  28  2319   113.0
# 15  2.602331  1610612752          NYK           7  50  32  18  2400   114.8
# 16  1.799562  1610612753          ORL          12  50  27  23  2415   110.2
# 17  2.085320  1610612754          IND          14  51  28  23  2448   117.9
# 18  2.469881  1610612755          PHI           6  48  30  18  2314   116.7
# 19  1.565554  1610612756          PHX          11  50  29  21  2415   115.8
# 20  2.231052  1610612757          POR          27  50  15  35  2425   106.1
# 21  2.069238  1610612758          SAC          15  48  29  19  2329   114.2
# 22  1.804374  1610612759          SAS          27  50  10  40  2410   107.4
# 23  2.213686  1610612760          OKC           2  50  35  15  2420   117.7
# 24  2.222124  1610612761          TOR          22  49  17  32  2372   112.5
# 25  2.310870  1610612762          UTA          24  51  25  26  2473   113.2
# 26  1.990579  1610612763          MEM          25  50  18  32  2410   104.6
# 27  1.865766  1610612764          WAS          26  49   9  40  2352   109.4
# 28  1.911873  1610612765          DET          29  49   6  43  2362   109.1
# 29  2.206133  1610612766          CHA          30  48  10  38  2314   107.6
#
#     DEFRTG  NETRTG
# 0    117.8    -2.6
# 1    109.0     9.1
# 2    108.0     5.5
# 3    111.0     4.2
# 4    112.2    -0.9
# 5    115.5    -0.3
# 6    112.3     3.4
# 7    115.0     0.1
# 8    109.6     1.2
# 9    110.8     7.2
# 10   112.5    -0.9
# 11   111.7    -0.7
# 12   114.2     4.0
# 13   105.9     6.5
# 14   114.2    -1.2
# 15   110.6     4.2
# 16   109.0     1.2
# 17   116.7     1.1
# 18   111.4     5.3
# 19   112.8     2.9
# 20   114.7    -8.6
# 21   114.0     0.2
# 22   116.0    -8.6
# 23   109.2     8.5
# 24   114.7    -2.2
# 25   115.9    -2.7
# 26   111.2    -6.6
# 27   117.5    -8.1
# 28   118.4    -9.2
# 29   118.9   -11.3

# %%
import plotly.express as px
fig = px.scatter(off_death_df, x="0", y="OFFRTG", color="abbreviation")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="36252076-1268-49b8-8b1c-9f24e39f777c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36252076-1268-49b8-8b1c-9f24e39f777c")) {                    Plotly.newPlot(                        "36252076-1268-49b8-8b1c-9f24e39f777c",                        [{"hovertemplate":"abbreviation=ATL\u003cbr\u003e0=%{x}\u003cbr\u003eOFFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ATL","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"ATL","orientation":"v","showlegend":true,"x":[1.9231527249018352],"xaxis":"x","y":[115.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=BOS\u003cbr\u003e0=%{x}\u003cbr\u003eOFFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BOS","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"BOS","orientation":"v","showlegend":true,"x":[2.448827022855932],"xaxis":"x","y":[118.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=CLE\u003cbr\u003e0=%{x}\u003cbr\u003eOFFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CLE","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"CLE","orientation":"v","showlegend":true,"x":[2.211224769552549],"xaxis":"x","y":[113.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=NOP\u003cbr\u003e0=%{x}\u003cbr\u003eOFFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NOP","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"NOP","orientation":"v","showlegend":true,"x":[1.965983821795537],"xaxis":"x","y":[115.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=CHI\u003cbr\u003e0=%{x}\u003cbr\u003eOFFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CHI","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"CHI","orientation":"v","showlegend":true,"x":[1.6252550303936004],"xaxis":"x","y":[111.3],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=DAL\u003cbr\u003e0=%{x}\u003cbr\u003eOFFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DAL","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"DAL","orientation":"v","showlegend":true,"x":[2.0990533576561856],"xaxis":"x","y":[115.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=DEN\u003cbr\u003e0=%{x}\u003cbr\u003eOFFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEN","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"DEN","orientation":"v","showlegend":true,"x":[1.9675671837546609],"xaxis":"x","y":[115.7],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=GSW\u003cbr\u003e0=%{x}\u003cbr\u003eOFFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GSW","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"GSW","orientation":"v","showlegend":true,"x":[2.375221454180204],"xaxis":"x","y":[115.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=HOU\u003cbr\u003e0=%{x}\u003cbr\u003eOFFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"HOU","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"HOU","orientation":"v","showlegend":true,"x":[2.1202412952076304],"xaxis":"x","y":[110.8],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=LAC\u003cbr\u003e0=%{x}\u003cbr\u003eOFFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LAC","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"LAC","orientation":"v","showlegend":true,"x":[1.8158487180868785],"xaxis":"x","y":[118.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=LAL\u003cbr\u003e0=%{x}\u003cbr\u003eOFFRTG=%{y}\u003cextra\u003e\u003c\u002fex ...

# %%
import statsmodels.api as sm

# Prepare the data
X = off_death_df["0"].values.reshape(-1, 1)
y = off_death_df["OFFRTG"].values

# Add a constant term to the design matrix
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     1.426
# Date:                Mon, 05 Feb 2024   Prob (F-statistic):              0.242
# Time:                        20:10:36   Log-Likelihood:                -80.905
# No. Observations:                  30   AIC:                             165.8
# Df Residuals:                      28   BIC:                             168.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        105.9457      5.996     17.668      0.000      93.663     118.229
# x1             3.4113      2.857      1.194      0.242      -2.441       9.263
# ==============================================================================
# Omnibus:                        1.223   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.543   Jarque-Bera (JB):                1.122
# Skew:                          -0.430   Prob(JB):                        0.571
# Kurtosis:                       2.603   Cond. No.                         22.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Defensive rating

# %%
team_defensive_space_dict = {}
for team in all_rosters:
  team_id = team['TeamID'].values[0]
  team_defensive_space_dict[team_id] = generate_team_defensive_space(team["PLAYER"].tolist(), defensive_data)

# %%
maxdim = 1
team_id = []
def_mean_deaths = {}

for i in range(maxdim):
  def_mean_deaths[str(i)] = []

for team in team_offensive_space_dict.keys():
  result = ripser(team_defensive_space_dict[team], maxdim=maxdim, do_cocycles=True)
  diagrams = result['dgms']

  for i in range(maxdim):
    resolutions_at_death = diagrams[i][:, 1]
    def_mean_deaths[str(i)].append(np.mean([j for j in resolutions_at_death if j != np.inf]))

  team_id.append(team)

# %%
def_death_df = pd.DataFrame(def_mean_deaths)
def_death_df['id'] = team_id
def_death_df = def_death_df.merge(pd.json_normalize(teams.get_teams()), left_on="id", right_on="id")
def_death_df = def_death_df.drop(["nickname", "city", "state", "year_founded", "full_name"], axis=1)
e_ratings = pd.read_csv("e_ratings.csv")
e_ratings = e_ratings.rename(columns={'TEAM': 'abbreviation'})
def_death_df = def_death_df.merge(e_ratings, on="abbreviation")

# %%
def_death_df
# Out:
#            0          id abbreviation  Unnamed: 0  GP   W   L   MIN  OFFRTG  \
# 0   2.386499  1610612737          ATL          23  49  22  27  2372   115.2
# 1   1.273116  1610612738          BOS           1  50  38  12  2425   118.2
# 2   1.556037  1610612739          CLE           5  47  31  16  2266   113.5
# 3   1.766305  1610612740          NOP           7  49  28  21  2357   115.2
# 4   1.792929  1610612741          CHI          19  50  23  27  2430   111.3
# 5   2.025830  1610612742          DAL          17  49  26  23  2352   115.2
# 6   1.465308  1610612743          DEN          10  51  35  16  2448   115.7
# 7   1.468428  1610612744          GSW          16  46  21  25  2238   115.1
# 8   1.356148  1610612745          HOU          12  49  23  26  2377   110.8
# 9   1.425765  1610612746          LAC           3  48  33  15  2309   118.0
# 10  1.679129  1610612747          LAL          19  51  26  25  2468   111.7
# 11  1.626221  1610612748          MIA          18  50  26  24  2405   111.1
# 12  1.383220  1610612749          MIL           9  50  33  17  2415   118.2
# 13  1.501809  1610612750          MIN           4  50  35  15  2410   112.4
# 14  1.681520  1610612751          BKN          21  48  20  28  2319   113.0
# 15  1.362876  1610612752          NYK           7  50  32  18  2400   114.8
# 16  1.875573  1610612753          ORL          12  50  27  23  2415   110.2
# 17  1.292433  1610612754          IND          14  51  28  23  2448   117.9
# 18  1.516674  1610612755          PHI           6  48  30  18  2314   116.7
# 19  1.409322  1610612756          PHX          11  50  29  21  2415   115.8
# 20  1.157749  1610612757          POR          27  50  15  35  2425   106.1
# 21  1.121160  1610612758          SAC          15  48  29  19  2329   114.2
# 22  1.203313  1610612759          SAS          27  50  10  40  2410   107.4
# 23  2.195184  1610612760          OKC           2  50  35  15  2420   117.7
# 24  1.620676  1610612761          TOR          22  49  17  32  2372   112.5
# 25  1.879326  1610612762          UTA          24  51  25  26  2473   113.2
# 26  1.503893  1610612763          MEM          25  50  18  32  2410   104.6
# 27  1.047161  1610612764          WAS          26  49   9  40  2352   109.4
# 28  1.340607  1610612765          DET          29  49   6  43  2362   109.1
# 29  1.190563  1610612766          CHA          30  48  10  38  2314   107.6
#
#     DEFRTG  NETRTG
# 0    117.8    -2.6
# 1    109.0     9.1
# 2    108.0     5.5
# 3    111.0     4.2
# 4    112.2    -0.9
# 5    115.5    -0.3
# 6    112.3     3.4
# 7    115.0     0.1
# 8    109.6     1.2
# 9    110.8     7.2
# 10   112.5    -0.9
# 11   111.7    -0.7
# 12   114.2     4.0
# 13   105.9     6.5
# 14   114.2    -1.2
# 15   110.6     4.2
# 16   109.0     1.2
# 17   116.7     1.1
# 18   111.4     5.3
# 19   112.8     2.9
# 20   114.7    -8.6
# 21   114.0     0.2
# 22   116.0    -8.6
# 23   109.2     8.5
# 24   114.7    -2.2
# 25   115.9    -2.7
# 26   111.2    -6.6
# 27   117.5    -8.1
# 28   118.4    -9.2
# 29   118.9   -11.3

# %%
import plotly.express as px
fig = px.scatter(def_death_df, x="0", y="DEFRTG", color="abbreviation")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e0927b57-08ae-4849-85fc-2ef405a2bbdc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0927b57-08ae-4849-85fc-2ef405a2bbdc")) {                    Plotly.newPlot(                        "e0927b57-08ae-4849-85fc-2ef405a2bbdc",                        [{"hovertemplate":"abbreviation=ATL\u003cbr\u003e0=%{x}\u003cbr\u003eDEFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ATL","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"ATL","orientation":"v","showlegend":true,"x":[2.386498806377252],"xaxis":"x","y":[117.8],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=BOS\u003cbr\u003e0=%{x}\u003cbr\u003eDEFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BOS","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"BOS","orientation":"v","showlegend":true,"x":[1.2731158895926042],"xaxis":"x","y":[109.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=CLE\u003cbr\u003e0=%{x}\u003cbr\u003eDEFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CLE","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"CLE","orientation":"v","showlegend":true,"x":[1.5560370633999507],"xaxis":"x","y":[108.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=NOP\u003cbr\u003e0=%{x}\u003cbr\u003eDEFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NOP","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"NOP","orientation":"v","showlegend":true,"x":[1.7663049697875977],"xaxis":"x","y":[111.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=CHI\u003cbr\u003e0=%{x}\u003cbr\u003eDEFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CHI","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"CHI","orientation":"v","showlegend":true,"x":[1.7929287731647492],"xaxis":"x","y":[112.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=DAL\u003cbr\u003e0=%{x}\u003cbr\u003eDEFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DAL","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"DAL","orientation":"v","showlegend":true,"x":[2.0258302367650547],"xaxis":"x","y":[115.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=DEN\u003cbr\u003e0=%{x}\u003cbr\u003eDEFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEN","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"DEN","orientation":"v","showlegend":true,"x":[1.465308427810669],"xaxis":"x","y":[112.3],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=GSW\u003cbr\u003e0=%{x}\u003cbr\u003eDEFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GSW","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"GSW","orientation":"v","showlegend":true,"x":[1.4684280970921884],"xaxis":"x","y":[115.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=HOU\u003cbr\u003e0=%{x}\u003cbr\u003eDEFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"HOU","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"HOU","orientation":"v","showlegend":true,"x":[1.35614797743884],"xaxis":"x","y":[109.6],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=LAC\u003cbr\u003e0=%{x}\u003cbr\u003eDEFRTG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LAC","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"LAC","orientation":"v","showlegend":true,"x":[1.4257646103700001],"xaxis":"x","y":[110.8],"yaxis":"y","type":"scatter"},{"hovertemplate":"abbreviation=LAL\u003cbr\u003e0=%{x}\u003cbr\u003eDEFRTG=%{y}\u003cextra\u003e\u003c\u002fex ...

# %%
import statsmodels.api as sm

# Prepare the data
X = def_death_df["0"].values.reshape(-1, 1)
y = def_death_df["DEFRTG"].values

# Add a constant term to the design matrix
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.017
# Method:                 Least Squares   F-statistic:                    0.5117
# Date:                Mon, 05 Feb 2024   Prob (F-statistic):              0.480
# Time:                        20:16:07   Log-Likelihood:                -77.575
# No. Observations:                  30   AIC:                             159.2
# Df Residuals:                      28   BIC:                             162.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        115.1755      3.069     37.525      0.000     108.888     121.463
# x1            -1.4004      1.958     -0.715      0.480      -5.411       2.610
# ==============================================================================
# Omnibus:                        0.337   Durbin-Watson:                   1.781
# Prob(Omnibus):                  0.845   Jarque-Bera (JB):                0.503
# Skew:                          -0.052   Prob(JB):                        0.778
# Kurtosis:                       2.375   Cond. No.                         11.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Merge data

# %%
death_df.rename(columns={"0": "NET_MEAN_H0_DEATH"}, inplace=True)
off_death_df.rename(columns={"MEAN_H0_DEATH": "OFF_MEAN_H0_DEATH"}, inplace=True)
def_death_df.rename(columns={"MEAN_H0_DEATH": "DEF_MEAN_H0_DEATH"}, inplace=True)

final_df = death_df.merge(off_death_df, on="id")
final_df = final_df.merge(def_death_df, on="id")
final_df["W_PCT"] = final_df["W"] / (final_df["W"] + final_df["L"])

# %%
final_df.columns
# Out:
# Index(['NET_MEAN_H0_DEATH', 'id', 'std', 'abbreviation_x', 'Unnamed: 0_x',
#        'GP_x', 'W_x', 'L_x', 'MIN_x', 'OFFRTG_x', 'DEFRTG_x', 'NETRTG_x',
#        'OFF_MEAN_H0_DEATH', 'abbreviation_y', 'Unnamed: 0_y', 'GP_y', 'W_y',
#        'L_y', 'MIN_y', 'OFFRTG_y', 'DEFRTG_y', 'NETRTG_y', 'DEF_MEAN_H0_DEATH',
#        'abbreviation', 'Unnamed: 0', 'GP', 'W', 'L', 'MIN', 'OFFRTG', 'DEFRTG',
#        'NETRTG', 'W_PCT'],
#       dtype='object')

# %%
cols = [
    "NET_MEAN_H0_DEATH",
    "OFF_MEAN_H0_DEATH",
    "DEF_MEAN_H0_DEATH",
    "id",
    "abbreviation_x",
    "W_x",
    "L_x",
    "OFFRTG_x",
    "DEFRTG_x",
    "NETRTG_x",
    "W_PCT"
]
final_df = final_df[cols]

# %%
final_df.to_csv("PERSISTENCE_MEANS.csv")
